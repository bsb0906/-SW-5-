# %%
# %matplotlib inline

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
map_GJ= gpd.GeoDataFrame.from_file('./LSMD_CONT_LDREG_서울_광진구/LSMD_CONT_LDREG_11215.shp', encoding='cp949')
map_GJ
# Out:
#        sgg_oid    jibun bchk                  pnu col_adm_se
# 0       201793  18-54 공    1  1121510200100180054      11215  \
# 1        83707  135-19도    1  1121510200101350019      11215
# 2        83772  135-35대    1  1121510200101350035      11215
# 3        83473     143대    1  1121510200101430000      11215
# 4        92539  553-59도    1  1121510500105530059      11215
# ...        ...      ...  ...                  ...        ...
# 32682    99225   57-96도    1  1121510500100570096      11215
# 32683    94139     720도    1  1121510500107200000      11215
# 32684    94140   721-1도    1  1121510500107210001      11215
# 32685    94141     721도    1  1121510500107210000      11215
# 32686   232881  680-1 도    1  1121510300106800001      11215
#
#                                                 geometry
# 0      POLYGON ((207056.900 550304.134, 207056.161 55...
# 1      POLYGON ((207250.092 550332.795, 207255.628 55...
# 2      POLYGON ((207267.052 550312.245, 207272.349 55...
# ...

# %%
print(map_GJ.crs)
# Out:
# None

# %%
map_GJ.set_crs(epsg=5186, inplace=True)
map_GJ = map_GJ.to_crs(epsg=4326)
map_GJ = map_GJ.to_crs({'init':'epsg:4326'})
# Out:
# C:\Users\bbcc6\AppData\Local\Programs\Python\Python310\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
map_GJ
# Out:
#        sgg_oid    jibun bchk                  pnu col_adm_se
# 0       201793  18-54 공    1  1121510200100180054      11215  \
# 1        83707  135-19도    1  1121510200101350019      11215
# 2        83772  135-35대    1  1121510200101350035      11215
# 3        83473     143대    1  1121510200101430000      11215
# 4        92539  553-59도    1  1121510500105530059      11215
# ...        ...      ...  ...                  ...        ...
# 32682    99225   57-96도    1  1121510500100570096      11215
# 32683    94139     720도    1  1121510500107200000      11215
# 32684    94140   721-1도    1  1121510500107210001      11215
# 32685    94141     721도    1  1121510500107210000      11215
# 32686   232881  680-1 도    1  1121510300106800001      11215
#
#                                                 geometry
# 0      POLYGON ((127.07986 37.55223, 127.07985 37.552...
# 1      POLYGON ((127.08205 37.55249, 127.08211 37.552...
# 2      POLYGON ((127.08224 37.55230, 127.08230 37.552...
# ...

# %%
map_hjd= gpd.GeoDataFrame.from_file('./Z_SOP_BND_ADM_DONG_PG\Z_SOP_BND_ADM_DONG_PG.shp', encoding='cp949')
map_hjd.head()

# 좌표계 변환 (과거 GRS80 중부원점에서 위도 경도 좌표계로)
map_hjd = map_hjd.to_crs({'init':'epsg:4326'})

# 광진구 행정동만 선택해서 추출
map_hjd_GJ = map_hjd[map_hjd['ADM_DR_CD'].str[0:5] == '11050']

using_columns = ['ADM_DR_CD', 'ADM_DR_NM', 'geometry']

# 필요한 열만 선택
map_hjd_GJ = map_hjd_GJ[using_columns]
map_hjd_GJ
# Out:
# C:\Users\bbcc6\AppData\Local\Programs\Python\Python310\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#    ADM_DR_CD ADM_DR_NM                                           geometry
# 65   1105053       화양동  POLYGON ((127.07047 37.54799, 127.07057 37.547...
# 66   1105054       군자동  POLYGON ((127.07924 37.55673, 127.07911 37.556...
# 67   1105055      중곡1동  POLYGON ((127.07950 37.55717, 127.07950 37.557...
# 68   1105056      중곡2동  POLYGON ((127.08574 37.56338, 127.08574 37.563...
# 69   1105057      중곡3동  POLYGON ((127.08062 37.57164, 127.08065 37.571...
# 70   1105058      중곡4동  POLYGON ((127.10166 37.57240, 127.10224 37.572...
# ...

# %%
using_columns = ['X_AXIS', 'Y_AXIS', '명칭', 'geometry']

# %%
dcC_SEOUL= gpd.GeoDataFrame.from_file('./XsDB_CHILDCARE_POI_TM/XsDB_어린이집_POI_TM.shp', encoding='cp949')
dcC_SEOUL.head()
# Out:
#   MEGA_NM MEGA_CD CTY_NM CTY_CD  X_AXIS  Y_AXIS        NM          배포처
# 0   서울특별시      11    강남구  11680  315817  546011  강남구청어린이집  biz-gis.com  \
# 1   서울특별시      11    강남구  11680  315817  546011  강남구청어린이집  biz-gis.com
# 2   서울특별시      11    강동구  11740  324195  550130   피터팬어린이집  biz-gis.com
# 3   서울특별시      11    강동구  11740  324195  550130   피터팬어린이집  biz-gis.com
# 4   서울특별시      11    강남구  11680  315817  546011  강남구청어린이집  biz-gis.com
#
#                         geometry
# 0  POINT (203957.577 445580.479)
# 1  POINT (203957.577 445580.479)
# 2  POINT (212291.622 449788.159)
# 3  POINT (212291.622 449788.159)
# 4  POINT (203957.577 445580.479)

# %%
dcC_SEOUL.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 39309 entries, 0 to 39308
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MEGA_NM   39309 non-null  object
#  1   MEGA_CD   39309 non-null  object
#  2   CTY_NM    39309 non-null  object
#  3   CTY_CD    39309 non-null  object
#  4   X_AXIS    39309 non-null  int64
#  5   Y_AXIS    39309 non-null  int64
#  6   NM        39309 non-null  object
#  7   배포처       39309 non-null  object
#  8   geometry  39309 non-null  geometry
# dtypes: geometry(1), int64(2), object(6)
# memory usage: 2.7+ MB

# %%
dcC_GJ = dcC_SEOUL[dcC_SEOUL['CTY_NM'] == "광진구"]

# %%
dcC_GJ.rename(columns={'NM':'명칭'}, inplace = True)
# Out:
# C:\Users\bbcc6\AppData\Local\Temp\ipykernel_20852\3228636243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dcC_GJ.rename(columns={'NM':'명칭'}, inplace = True)

# %%
dcC_GJ.head()
# Out:
#      MEGA_NM MEGA_CD CTY_NM CTY_CD  X_AXIS  Y_AXIS         명칭          배포처
# 1381   서울특별시      11    광진구  11215  317947  549738  건대사임당어린이집  biz-gis.com  \
# 1382   서울특별시      11    광진구  11215  318352  550784     경성어린이집  biz-gis.com
# 1383   서울특별시      11    광진구  11215  319995  550384     경원어린이집  biz-gis.com
# 1384   서울특별시      11    광진구  11215  321136  549636     광남어린이집  biz-gis.com
# 1385   서울특별시      11    광진구  11215  317983  548274     광무어린이집  biz-gis.com
#
#                            geometry
# 1381  POINT (206047.979 449329.907)
# 1382  POINT (206441.869 450380.162)
# 1383  POINT (208089.053 449997.604)
# 1384  POINT (209237.949 449261.730)
# 1385  POINT (206099.501 447866.345)

# %%
dcC_GJ['MEGA_NM'].unique()
# Out:
# array(['서울특별시'], dtype=object)

# %%
dcC_GJ['MEGA_CD'].unique()
# Out:
# array(['11'], dtype=object)

# %%
dcC_GJ['CTY_NM'].unique()
# Out:
# array(['광진구'], dtype=object)

# %%
dcC_GJ['CTY_CD'].unique()
# Out:
# array(['11215'], dtype=object)

# %%
dcC_GJ['X_AXIS'].unique()
# Out:
# array([317947, 318352, 319995, 321136, 317983, 320794, 320333, 320413,
#        319086, 318769, 320338, 320228, 319283, 319974, 319720, 320022,
#        318262, 320954, 319790, 320122, 319959, 319733, 319832, 320093,
#        319090, 319196, 318561, 319203, 320904, 318729, 319725, 319198,
#        319767, 319080, 321048, 319182, 318603, 318445, 319700, 319628,
#        318950, 318573, 317430, 319908, 318660, 319335, 317661, 319452,
#        319663, 319163, 319480, 319560, 319451, 317868, 317669, 317549,
#        318967, 319444, 318882, 319412, 317889, 320163, 318827, 319029,
#        319060, 318407, 318562, 319232, 319056, 320357, 319471, 319051,
#        320017, 318088, 319481, 321643, 317647, 318012, 319658, 319016,
#        318613, 319007, 317491, 320552, 319351, 318519, 318709, 318980,
#        318333, 319290, 319926, 319132, 319661, 319912, 320081, 320360,
#        318566, 319512, 319020, 319316, 319169, 317315, 319374, 319175,
# ...

# %%
dcC_GJ['Y_AXIS'].unique()
# Out:
# array([549738, 550784, 550384, 549636, 548274, 549457, 549305, 549141,
#        548861, 548729, 550158, 548954, 547793, 550373, 550053, 548672,
#        550663, 549795, 550965, 550411, 548936, 550936, 550599, 550652,
#        548142, 548996, 550798, 550695, 549967, 549642, 550844, 551916,
#        550714, 550544, 549854, 550650, 550799, 548169, 550761, 549603,
#        547888, 550407, 548029, 549378, 548244, 549439, 548965, 551104,
#        549035, 548011, 549144, 551574, 549043, 548411, 549126, 548446,
#        551961, 552389, 547801, 549464, 549581, 548767, 551323, 551012,
#        547769, 548640, 551447, 548111, 548557, 550442, 550722, 552358,
#        548155, 550770, 549691, 548243, 550301, 548974, 550310, 549888,
#        552412, 548306, 551541, 548424, 549404, 550875, 550732, 548612,
#        551988, 550952, 551557, 549462, 547873, 549180, 550355, 550846,
#        548818, 547972, 550887, 548393, 551260, 547894, 548623, 549219,
# ...

# %%
dcC_GJ['명칭'].unique()
# Out:
# array(['건대사임당어린이집', '경성어린이집', '경원어린이집', '광남어린이집', '광무어린이집', '광장사임당어린이집',
#        '광장아이자람어린이집', '광장어린이집', '광진구청직장어린이집', '광진어린이집', '구립구의2동어린이집',
#        '구립구의3동어린이집', '구립자양2동어린이집', '구의사임당어린이집', '구의어린이집', '구의현대사임당',
#        '군자어린이집', '굿모닝어린이집', '궁전어린이집', '금색동어린이집', '꼬꼬마어린이집', '꼬마뜰어린이집',
#        '꼬마별어린이집', '꽃사슴어린이집', '꾸러기어린이집', '꿈나무어린이집', '꿈동산몬테소리어린이집',
#        '꿈터대공원어린이집', '나섬어린이집', '느티나무어린이집', '늘사랑어린이집', '늘평화어린이집',
#        '늘푸른몬테소리어린이집', '능동어린이집', '다예린어린이집', '대공원어린이집', '대동어린이집', '대서울어린이집',
#        '대원어린이집', '대일어린이집', '데커어린이집', '도시철도공사대공원어린이집', '돌고래어린이집',
#        '동서울어린이집', '동심어린이집', '동원어린이집', '동화나라어린이집', '동화어린이집', '또래어린이집',
#        '러브러브어린이집', '리틀지니어스', '맘스맘용마어린이집', '명성어린이집', '무지개어린이집', '물고기어린이집',
#        '미래어린이집', '미예뜰어린이집', '미파어린이집', '민들레어린이집', '민어린이집', '민주어린이집',
#        '바니스쿨어린이집', '바른선어린이집', '방울어린이집', '보람어린이집', '보배어린이집', '삐아제이삭어린이집',
#        '사랑의어린이집', '사랑해어린이집', '사임당어린이집', '산들어린이집', '산위의마을어린이집', '상명어린이집',
# ...

# %%
dcC_GJ['배포처'].unique()
# Out:
# array(['biz-gis.com'], dtype=object)

# %%
dcC_GJ['geometry'].unique()
# Out:
# <GeometryArray>
# [<POINT (206047.979 449329.907)>, <POINT (206441.869 450380.162)>,
#  <POINT (208089.053 449997.604)>,  <POINT (209237.949 449261.73)>,
#  <POINT (206099.501 447866.345)>, <POINT (208897.858 449079.109)>,
#  <POINT (208438.485 448922.226)>, <POINT (208520.221 448759.079)>,
#  <POINT (207196.236 448465.018)>, <POINT (206880.648 448329.662)>,
#  ...
#  <POINT (206159.813 449912.136)>, <POINT (206696.806 448407.718)>,
#   <POINT (206576.219 447613.38)>, <POINT (207260.102 450646.862)>,
#  <POINT (205943.994 449327.804)>, <POINT (206207.506 449375.602)>,
#  <POINT (206454.904 448208.139)>,  <POINT (207860.44 449205.118)>,
#  <POINT (206140.711 448129.802)>,  <POINT (205965.52 449184.022)>]
# Length: 202, dtype: geometry

# %%
dcC_GJ = dcC_GJ[using_columns]
dcC_GJ
# Out:
#       X_AXIS  Y_AXIS          명칭                       geometry
# 1381  317947  549738   건대사임당어린이집  POINT (206047.979 449329.907)
# 1382  318352  550784      경성어린이집  POINT (206441.869 450380.162)
# 1383  319995  550384      경원어린이집  POINT (208089.053 449997.604)
# 1384  321136  549636      광남어린이집  POINT (209237.949 449261.730)
# 1385  317983  548274      광무어린이집  POINT (206099.501 447866.345)
# ...      ...     ...         ...                            ...
# 1585  318107  549782      화양어린이집  POINT (206207.506 449375.602)
# 1586  318342  548612      효지어린이집  POINT (206454.904 448208.139)
# 1587  319758  549594    휴먼시아어린이집  POINT (207860.440 449205.118)
# 1588  318027  548537  희망아뜰리에어린이집  POINT (206140.711 448129.802)
# 1589  317863  549593      EQ어린이집  POINT (205965.520 449184.022)
#
# [209 rows x 4 columns]

# %%
print(dcC_GJ.crs)
# Out:
# None

# %%
dcC_GJ.set_crs(epsg=5174, inplace=True)
dcC_GJ = dcC_GJ.to_crs(epsg=4326)
dcC_GJ = dcC_GJ.to_crs({'init':'epsg:4326'})
# Out:
# C:\Users\bbcc6\AppData\Local\Programs\Python\Python310\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
dcC_GJ
# Out:
#       X_AXIS  Y_AXIS          명칭                    geometry
# 1381  317947  549738   건대사임당어린이집  POINT (127.06923 37.54621)
# 1382  318352  550784      경성어린이집  POINT (127.07369 37.55567)
# 1383  319995  550384      경원어린이집  POINT (127.09233 37.55221)
# 1384  321136  549636      광남어린이집  POINT (127.10532 37.54557)
# 1385  317983  548274      광무어린이집  POINT (127.06980 37.53302)
# ...      ...     ...         ...                         ...
# 1585  318107  549782      화양어린이집  POINT (127.07103 37.54662)
# 1586  318342  548612      효지어린이집  POINT (127.07382 37.53610)
# 1587  319758  549594    휴먼시아어린이집  POINT (127.08973 37.54507)
# 1588  318027  548537  희망아뜰리에어린이집  POINT (127.07027 37.53540)
# 1589  317863  549593      EQ어린이집  POINT (127.06829 37.54490)
#
# [209 rows x 4 columns]

# %%
dcC_GJ = gpd.sjoin(dcC_GJ.to_crs(epsg=4326), map_GJ)
dcC_GJ.drop(['index_right','bchk'], axis=1, inplace = True)
# Out:
# C:\Users\bbcc6\AppData\Local\Temp\ipykernel_20852\1981259511.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: +init=epsg:4326 +type=crs
#
#   dcC_GJ = gpd.sjoin(dcC_GJ.to_crs(epsg=4326), map_GJ)

# %%
# 버스정류장이 속한 행정동 추가
dcC_GJ = gpd.sjoin(dcC_GJ.to_crs(epsg=4326), map_hjd_GJ)
# Out:
# C:\Users\bbcc6\AppData\Local\Temp\ipykernel_20852\1536228464.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: +init=epsg:4326 +type=crs
#
#   dcC_GJ = gpd.sjoin(dcC_GJ.to_crs(epsg=4326), map_hjd_GJ)

# %%
dcC_GJ.drop(['index_right','col_adm_se'], axis=1, inplace = True)
dcC_GJ
# Out:
#       X_AXIS  Y_AXIS         명칭                    geometry  sgg_oid
# 1381  317947  549738  건대사임당어린이집  POINT (127.06923 37.54621)   100176  \
# 1410  318729  549642   느티나무어린이집  POINT (127.07809 37.54542)   102184
# 1441  317889  549581     민주어린이집  POINT (127.06859 37.54479)   100740
# 1456  318088  549691     새봄어린이집  POINT (127.07083 37.54580)   247698
# 1506  317933  549833     예손어린이집  POINT (127.06906 37.54707)   106207
# ...      ...     ...        ...                         ...      ...
# 1522  318795  551568     자람어린이집  POINT (127.07862 37.56277)    76622
# 1526  319074  551736     정아어린이집  POINT (127.08176 37.56431)    75774
# 1531  318884  551369   중곡1동어린이집  POINT (127.07965 37.56099)   106324
# 1546  318935  551759   초록마을어린이집  POINT (127.08018 37.56451)   230962
# 1566  318704  551365     한빛어린이집  POINT (127.07761 37.56094)    77968
#
#          jibun                  pnu ADM_DR_CD ADM_DR_NM
# 1381    17-66대  1121510700100170066   1105053       화양동
# ...

# %%
ax = map_GJ.plot(figsize=(8,8), alpha=0.8)
dcC_GJ.plot(ax=ax, marker='v', column='ADM_DR_NM', label='dcC')
ax.set_axis_off()
plt.legend()
plt.show()

# %%
chH_SEOUL= gpd.GeoDataFrame.from_file('./XsDB_KINDERGARTEN_POI_TM/XsDB_유치원_POI_TM.shp', encoding='cp949')
chH_SEOUL.head()
# Out:
#   MEGA_NM MEGA_CD CTY_NM CTY_CD  X_AXIS  Y_AXIS               NM          배포처
# 0   서울특별시      11    종로구  11110  308985  553398  배화여자대학 병설 배화유치원  biz-gis.com  \
# 1   서울특별시      11    종로구  11110  312447  552802            봄샘유치원  biz-gis.com
# 2   서울특별시      11    종로구  11110  308003  556109        상명사대부속유치원  biz-gis.com
# 3   서울특별시      11    종로구  11110  313119  553721    서울명신초등학교병설유치원  biz-gis.com
# 4   서울특별시      11    종로구  11110  313878  553102    서울숭신초등학교병설유치원  biz-gis.com
#
#                         geometry
# 0  POINT (197047.585 452894.651)
# 1  POINT (200515.721 452335.424)
# 2  POINT (196036.863 455595.066)
# 3  POINT (201177.934 453261.509)
# 4  POINT (201943.467 452650.595)

# %%
chH_GJ = chH_SEOUL[chH_SEOUL['CTY_NM'] == "광진구"]

# %%
chH_GJ.rename(columns={'NM':'명칭'}, inplace = True)
# Out:
# C:\Users\bbcc6\AppData\Local\Temp\ipykernel_20852\2920011383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chH_GJ.rename(columns={'NM':'명칭'}, inplace = True)

# %%
chH_GJ = chH_GJ[using_columns]
chH_GJ
# Out:
#      X_AXIS  Y_AXIS             명칭                       geometry
# 71   318763  551943          경하유치원  POINT (206840.559 451543.479)
# 72   320528  549083          광남유치원  POINT (208635.832 448702.301)
# 73   319510  551607          금빛유치원  POINT (207591.096 451215.417)
# 74   319360  549442          동인유치원  POINT (207464.066 449048.903)
# 75   319444  552389          미파유치원  POINT (207516.802 451996.689)
# 76   319933  549304          샬롬유치원  POINT (208038.509 448916.984)
# 77   318928  549346  서울구의초등학교병설유치원  POINT (207033.099 448948.325)
# 78   318487  547942  서울신자초등학교병설유치원  POINT (206607.002 447539.701)
# 79   319742  548003  서울양남초등학교병설유치원  POINT (207861.310 447614.004)
# 80   318848  548684  서울자양초등학교병설유치원  POINT (206960.122 448285.501)
# 81   319723  548255          선경유치원  POINT (207839.639 447865.793)
# 82   318296  550847          선미유치원  POINT (206385.203 450442.566)
# 83   318128  550637          선양유치원  POINT (206219.437 450230.792)
# ...

# %%
print(chH_GJ.crs)
# Out:
# None

# %%
chH_GJ.set_crs(epsg=5174, inplace=True)
chH_GJ = chH_GJ.to_crs(epsg=4326)
chH_GJ = chH_GJ.to_crs({'init':'epsg:4326'})
# Out:
# C:\Users\bbcc6\AppData\Local\Programs\Python\Python310\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
chH_GJ
# Out:
#      X_AXIS  Y_AXIS             명칭                    geometry
# 71   318763  551943          경하유치원  POINT (127.07822 37.56615)
# 72   320528  549083          광남유치원  POINT (127.09850 37.54054)
# 73   319510  551607          금빛유치원  POINT (127.08671 37.56319)
# 74   319360  549442          동인유치원  POINT (127.08525 37.54367)
# 75   319444  552389          미파유치원  POINT (127.08587 37.57023)
# 76   319933  549304          샬롬유치원  POINT (127.09175 37.54248)
# 77   318928  549346  서울구의초등학교병설유치원  POINT (127.08037 37.54277)
# 78   318487  547942  서울신자초등학교병설유치원  POINT (127.07554 37.53008)
# 79   319742  548003  서울양남초등학교병설유치원  POINT (127.08973 37.53074)
# 80   318848  548684  서울자양초등학교병설유치원  POINT (127.07954 37.53679)
# 81   319723  548255          선경유치원  POINT (127.08948 37.53301)
# 82   318296  550847          선미유치원  POINT (127.07305 37.55623)
# 83   318128  550637          선양유치원  POINT (127.07117 37.55433)
# 84   319551  550184          선화유치원  POINT (127.08733 37.55037)
# ...

# %%
chH_GJ = gpd.sjoin(chH_GJ.to_crs(epsg=4326), map_GJ)
chH_GJ.drop(['index_right','bchk', 'col_adm_se'],axis=1, inplace = True)
# Out:
# C:\Users\bbcc6\AppData\Local\Temp\ipykernel_20852\3648307345.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: +init=epsg:4326 +type=crs
#
#   chH_GJ = gpd.sjoin(chH_GJ.to_crs(epsg=4326), map_GJ)

# %%
# 버스정류장이 속한 행정동 추가
chH_GJ = gpd.sjoin(chH_GJ.to_crs(epsg=4326), map_hjd_GJ)

chH_GJ.drop(['index_right'], axis=1, inplace = True)
chH_GJ
# Out:
# C:\Users\bbcc6\AppData\Local\Temp\ipykernel_20852\1158164711.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: +init=epsg:4326 +type=crs
#
#   chH_GJ = gpd.sjoin(chH_GJ.to_crs(epsg=4326), map_hjd_GJ)
#      X_AXIS  Y_AXIS             명칭                    geometry  sgg_oid
# 71   318763  551943          경하유치원  POINT (127.07822 37.56615)    75103  \
# 75   319444  552389          미파유치원  POINT (127.08587 37.57023)    73331
# 88   318963  551948        아이조아유치원  POINT (127.08048 37.56621)    75095
# 102  319018  552412         동서울유치원  POINT (127.08105 37.57040)    73264
# 107  319374  552203        한국중앙유치원  POINT (127.08510 37.56855)    73996
# 72   320528  549083          광남유치원  POINT (127.09850 37.54054)   128513
# 96   320334  549302        청구이화유치원  POINT (127.09628 37.54249)    91320
# ...

# %%
ax = map_GJ.plot(figsize=(8,8), alpha=0.8)
chH_GJ.plot(ax=ax, marker='v', column='ADM_DR_NM', label='chH')
ax.set_axis_off()
plt.legend()
plt.show()

# %%
ax = map_GJ.plot(figsize=(8,8), alpha=0.8, color='green')
dcC_GJ.plot(ax=ax, marker='v', column='ADM_DR_NM', label='dcC')
chH_GJ.plot(ax=ax, marker='*', column='ADM_DR_NM', label='chH')
ax.set_axis_off()
plt.legend()
plt.show()

# %%
dcC_GJ.to_csv('./daycarecenter_gwangjin.csv')
chH_GJ.to_csv('./childrenHouse_gwangjin.csv')

# %%
dcC_GJ['시설 명'] = '어린이집'
chH_GJ['시설 명'] = '유치원'

# %%
result = pd.concat([dcC_GJ,chH_GJ])
result
# Out:
#       X_AXIS  Y_AXIS         명칭                    geometry  sgg_oid
# 1381  317947  549738  건대사임당어린이집  POINT (127.06923 37.54621)   100176  \
# 1410  318729  549642   느티나무어린이집  POINT (127.07809 37.54542)   102184
# 1441  317889  549581     민주어린이집  POINT (127.06859 37.54479)   100740
# 1456  318088  549691     새봄어린이집  POINT (127.07083 37.54580)   247698
# 1506  317933  549833     예손어린이집  POINT (127.06906 37.54707)   106207
# ...      ...     ...        ...                         ...      ...
# 108   319998  550333    한마음미술학원  POINT (127.09237 37.55175)    84711
# 91    318491  548420      우성유치원  POINT (127.07553 37.53438)    93576
# 93    317858  548362      인애유치원  POINT (127.06837 37.53381)    93998
# 98    318147  548604      한일유치원  POINT (127.07162 37.53601)    92482
# 104   318694  551077      삼원유치원  POINT (127.07753 37.55834)    80180
#
#          jibun                  pnu ADM_DR_CD ADM_DR_NM  시설 명
# 1381    17-66대  1121510700100170066   1105053       화양동  어린이집
# ...

# %%
new1 = dcC_GJ.groupby(['ADM_DR_NM']).agg({'명칭':'count'})
new1.rename(columns={'명칭':'어린이집 수'}, inplace = True)
new1.sort_values('어린이집 수',ascending = False, inplace = True)

# %%
new1.loc['총합'] = new1.sum(axis=0)
new1
# Out:
#            어린이집 수
# ADM_DR_NM
# 중곡4동           22
# 구의2동           21
# 자양2동           17
# 광장동            15
# 군자동            15
# 자양1동           15
# 자양3동           15
# 중곡2동           14
# 구의3동           13
# 자양4동           13
# 중곡3동           12
# 화양동            11
# 구의1동           10
# 중곡1동           10
# 능동              6
# 총합            209

# %%
new2 = chH_GJ.groupby(['ADM_DR_NM']).agg({'명칭':'count'})
new2.rename(columns={'명칭':'유치원 수'}, inplace = True)
new2.sort_values('유치원 수',ascending = False, inplace = True)

# %%
new2.loc['총합'] = new2.sum(axis=0)
new2
# Out:
#            유치원 수
# ADM_DR_NM
# 중곡3동           5
# 구의2동           4
# 자양2동           4
# 광장동            3
# 군자동            3
# 자양1동           3
# 자양3동           3
# 구의1동           2
# 구의3동           2
# 능동             2
# 자양4동           2
# 중곡2동           2
# 화양동            2
# 중곡1동           1
# 총합            38

# %%
new3 = result.groupby(['ADM_DR_NM']).agg({'명칭':'count'})
new3.rename(columns={'명칭':'아동 돌봄시설 수'}, inplace = True)
new3.sort_values('아동 돌봄시설 수',ascending = False, inplace = True)

# %%
new3.loc['총합'] = new3.sum(axis=0)
new3
# Out:
#            아동 돌봄시설 수
# ADM_DR_NM
# 구의2동              25
# 중곡4동              22
# 자양2동              21
# 광장동               18
# 군자동               18
# 자양1동              18
# 자양3동              18
# 중곡3동              17
# 중곡2동              16
# 구의3동              15
# 자양4동              15
# 화양동               13
# 구의1동              12
# 중곡1동              11
# 능동                 8
# 총합               247

# %%
result.to_file('./childrencare_GwangJin/childrencare_GwangJin.shp',encoding='euc-kr')

# %%
result
# Out:
#       X_AXIS  Y_AXIS         명칭                    geometry  sgg_oid
# 1381  317947  549738  건대사임당어린이집  POINT (127.06923 37.54621)   100176  \
# 1410  318729  549642   느티나무어린이집  POINT (127.07809 37.54542)   102184
# 1441  317889  549581     민주어린이집  POINT (127.06859 37.54479)   100740
# 1456  318088  549691     새봄어린이집  POINT (127.07083 37.54580)   247698
# 1506  317933  549833     예손어린이집  POINT (127.06906 37.54707)   106207
# ...      ...     ...        ...                         ...      ...
# 108   319998  550333    한마음미술학원  POINT (127.09237 37.55175)    84711
# 91    318491  548420      우성유치원  POINT (127.07553 37.53438)    93576
# 93    317858  548362      인애유치원  POINT (127.06837 37.53381)    93998
# 98    318147  548604      한일유치원  POINT (127.07162 37.53601)    92482
# 104   318694  551077      삼원유치원  POINT (127.07753 37.55834)    80180
#
#          jibun                  pnu ADM_DR_CD ADM_DR_NM  시설 명
# 1381    17-66대  1121510700100170066   1105053       화양동  어린이집
# ...

# %%
result.rename(columns={'명칭':'name','시설 명':'type_name'}, inplace = True)
